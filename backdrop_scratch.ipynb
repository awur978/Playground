# %%
import numpy as np
from random import random
from random import seed
#Define activation function
def activation_function(activation):
    return 1.0/(1.0 + np.exp(-activation))
# Calculate the derivative of an neuron output
def activation_derivative(output):
    return output * (1.0 - output)

# %%
#Initialize a network
'''Arguments
    n_inputs: number of inputs
    n_hidden: number of neurons in the hidden layer (SLFNN)
    n_ouputs: number of classes'''
def initialize_network(n_inputs,n_hidden,n_outputs):
    #organising the layers as arrays of dictionaries so as to treat the whole net as an array of layers
    network = list() #Using the list() constructor to make a List
    hidden_layer = [{'weights': [random() for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_layer)
    output_layer = [{'weights': [random() for i in range(n_hidden + 1)]} for i in range(n_outputs)]
    network.append(output_layer)
    return network

# %%
#Forward propagation
#Weighted sum calculation
def weighted_sum(weights, inputs):
    activation = weights[-1]
    for i in range(len(weights)-1):
        activation += weights[i] * inputs[i]
    return activation


#Froward propagate through the whole network
def forward(network, row):
    inputs = row
    for layer in network:
        new_inputs = []
        for neuron in layer:
            activation = weighted_sum(neuron['weights'], inputs)
            neuron['output'] = activation_function(activation)
            new_inputs.append(neuron['output'])
            inputs = new_inputs
        return inputs

# %%
network = [[{'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614]}],
           [{'weights': [0.2550690257394217, 0.49543508709194095]}, {'weights': [0.4494910647887381, 0.651592972722763]}]]
row = [1, 0, None]
output = forward(network, row)
print(output)
# Out:
# [0.71056688831159409]

# %%
# Backpropagate error and store in neurons
def backward_propagate_error(network, expected):
    for i in reversed(range(len(network))):
        layer = network[i]
        errors = list()
        if i != len(network)-1:
            for j in range(len(layer)):
                error = 0.0
                for neuron in network[i + 1]:
                    error += (neuron['weights'][j] * neuron['delta'])
                errors.append(error)
        else:
            for j in range(len(layer)):
                neuron = layer[j]
                errors.append(expected[j] - neuron['output'])
        for j in range(len(layer)):
            neuron = layer[j]
            neuron['delta'] = errors[j] * transfer_derivative(neuron['output'])

# %%
# Update network weights with error
def update_weights(network, row, l_rate):
    for i in range(len(network)):
        inputs = row[:-1]
        if i != 0:
            inputs = [neuron['output'] for neuron in network[i - 1]]
        for neuron in network[i]:
            for j in range(len(inputs)):
                neuron['weights'][j] += l_rate * neuron['delta'] * inputs[j]
            neuron['weights'][-1] += l_rate * neuron['delta']

# %%
# Train a network for a fixed number of epochs
def train_network(network, train, l_rate, n_epoch, n_outputs):
    for epoch in range(n_epoch):
        sum_error = 0
        for row in train:
            outputs = forward(network, row)
            expected = [0 for i in range(n_outputs)]
            expected[row[-1]] = 1
            sum_error += sum([(expected[i]-outputs[i])**2 for i in range(len(expected))])
            backward_propagate_error(network, expected)
            update_weights(network, row, l_rate)
        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))

# %%
# Test training backprop algorithm
seed(1)
dataset = [[2.7810836,2.550537003,0],
           [1.465489372,2.362125076,0],
           [3.396561688,4.400293529,0],
           [1.38807019,1.850220317,0],
           [3.06407232,3.005305973,0],
           [7.627531214,2.759262235,1],
           [5.332441248,2.088626775,1],
           [6.922596716,1.77106367,1],
           [8.675418651,-0.242068655,1],
           [7.673756466,3.508563011,1]]
n_inputs = len(dataset[0]) - 1
n_outputs = len(set([row[-1] for row in dataset]))
network = initialize_network(n_inputs, 2, n_outputs)
train_network(network, dataset, 0.5, 1000, n_outputs)
#for layer in network:
#    print(layer)
# Out:
# >epoch=0, lrate=0.500, error=6.350
# >epoch=1, lrate=0.500, error=5.531
# >epoch=2, lrate=0.500, error=5.221
# >epoch=3, lrate=0.500, error=4.951
# >epoch=4, lrate=0.500, error=4.519
# >epoch=5, lrate=0.500, error=4.173
# >epoch=6, lrate=0.500, error=3.835
# >epoch=7, lrate=0.500, error=3.506
# >epoch=8, lrate=0.500, error=3.192
# >epoch=9, lrate=0.500, error=2.898
# >epoch=10, lrate=0.500, error=2.626
# >epoch=11, lrate=0.500, error=2.377
# >epoch=12, lrate=0.500, error=2.153
# >epoch=13, lrate=0.500, error=1.953
# >epoch=14, lrate=0.500, error=1.774
# >epoch=15, lrate=0.500, error=1.614
# >epoch=16, lrate=0.500, error=1.472
# >epoch=17, lrate=0.500, error=1.346
# >epoch=18, lrate=0.500, error=1.233
# >epoch=19, lrate=0.500, error=1.132
# >epoch=20, lrate=0.500, error=1.042
# >epoch=21, lrate=0.500, error=0.961
# >epoch=22, lrate=0.500, error=0.887
# >epoch=23, lrate=0.500, error=0.821
# >epoch=24, lrate=0.500, error=0.761
# >epoch=25, lrate=0.500, error=0.707
# >epoch=26, lrate=0.500, error=0.658
# >epoch=27, lrate=0.500, error=0.613
# >epoch=28, lrate=0.500, error=0.573
# >epoch=29, lrate=0.500, error=0.536
# >epoch=30, lrate=0.500, error=0.503
# >epoch=31, lrate=0.500, error=0.472
# >epoch=32, lrate=0.500, error=0.445
# >epoch=33, lrate=0.500, error=0.420
# >epoch=34, lrate=0.500, error=0.397
# >epoch=35, lrate=0.500, error=0.376
# >epoch=36, lrate=0.500, error=0.356
# >epoch=37, lrate=0.500, error=0.339
# >epoch=38, lrate=0.500, error=0.322
# >epoch=39, lrate=0.500, error=0.307
# >epoch=40, lrate=0.500, error=0.293
# >epoch=41, lrate=0.500, error=0.280
# >epoch=42, lrate=0.500, error=0.268
# >epoch=43, lrate=0.500, error=0.257
# >epoch=44, lrate=0.500, error=0.247
# >epoch=45, lrate=0.500, error=0.237
# >epoch=46, lrate=0.500, error=0.228
# >epoch=47, lrate=0.500, error=0.220
# >epoch=48, lrate=0.500, error=0.212
# >epoch=49, lrate=0.500, error=0.204
# >epoch=50, lrate=0.500, error=0.197
# >epoch=51, lrate=0.500, error=0.191
# >epoch=52, lrate=0.500, error=0.185
# >epoch=53, lrate=0.500, error=0.179
# >epoch=54, lrate=0.500, error=0.173
# >epoch=55, lrate=0.500, error=0.168
# >epoch=56, lrate=0.500, error=0.163
# >epoch=57, lrate=0.500, error=0.158
# >epoch=58, lrate=0.500, error=0.154
# >epoch=59, lrate=0.500, error=0.150
# >epoch=60, lrate=0.500, error=0.146
# >epoch=61, lrate=0.500, error=0.142
# >epoch=62, lrate=0.500, error=0.138
# >epoch=63, lrate=0.500, error=0.135
# >epoch=64, lrate=0.500, error=0.131
# >epoch=65, lrate=0.500, error=0.128
# >epoch=66, lrate=0.500, error=0.125
# >epoch=67, lrate=0.500, error=0.122
# >epoch=68, lrate=0.500, error=0.119
# >epoch=69, lrate=0.500, error=0.117
# >epoch=70, lrate=0.500, error=0.114
# >epoch=71, lrate=0.500, error=0.112
# >epoch=72, lrate=0.500, error=0.109
# >epoch=73, lrate=0.500, error=0.107
# >epoch=74, lrate=0.500, error=0.105
# >epoch=75, lrate=0.500, error=0.103
# >epoch=76, lrate=0.500, error=0.101
# >epoch=77, lrate=0.500, error=0.099
# >epoch=78, lrate=0.500, error=0.097
# >epoch=79, lrate=0.500, error=0.095
# >epoch=80, lrate=0.500, error=0.093
# >epoch=81, lrate=0.500, error=0.092
# >epoch=82, lrate=0.500, error=0.090
# >epoch=83, lrate=0.500, error=0.088
# >epoch=84, lrate=0.500, error=0.087
# >epoch=85, lrate=0.500, error=0.085
# >epoch=86, lrate=0.500, error=0.084
# >epoch=87, lrate=0.500, error=0.083
# >epoch=88, lrate=0.500, error=0.081
# >epoch=89, lrate=0.500, error=0.080
# >epoch=90, lrate=0.500, error=0.079
# >epoch=91, lrate=0.500, error=0.077
# >epoch=92, lrate=0.500, error=0.076
# >epoch=93, lrate=0.500, error=0.075
# >epoch=94, lrate=0.500, error=0.074
# >epoch=95, lrate=0.500, error=0.073
# >epoch=96, lrate=0.500, error=0.072
# >epoch=97, lrate=0.500, error=0.071
# >epoch=98, lrate=0.500, error=0.070
# >epoch=99, lrate=0.500, error=0.069
# >epoch=100, lrate=0.500, error=0.068
# >epoch=101, lrate=0.500, error=0.067
# >epoch=102, lrate=0.500, error=0.066
# >epoch=103, lrate=0.500, error=0.065
# >epoch=104, lrate=0.500, error=0.064
# >epoch=105, lrate=0.500, error=0.063
# >epoch=106, lrate=0.500, error=0.062
# >epoch=107, lrate=0.500, error=0.062
# >epoch=108, lrate=0.500, error=0.061
# >epoch=109, lrate=0.500, error=0.060
# >epoch=110, lrate=0.500, error=0.059
# >epoch=111, lrate=0.500, error=0.059
# >epoch=112, lrate=0.500, error=0.058
# >epoch=113, lrate=0.500, error=0.057
# >epoch=114, lrate=0.500, error=0.057
# >epoch=115, lrate=0.500, error=0.056
# >epoch=116, lrate=0.500, error=0.055
# >epoch=117, lrate=0.500, error=0.055
# >epoch=118, lrate=0.500, error=0.054
# >epoch=119, lrate=0.500, error=0.053
# >epoch=120, lrate=0.500, error=0.053
# >epoch=121, lrate=0.500, error=0.052
# >epoch=122, lrate=0.500, error=0.052
# >epoch=123, lrate=0.500, error=0.051
# >epoch=124, lrate=0.500, error=0.050
# >epoch=125, lrate=0.500, error=0.050
# >epoch=126, lrate=0.500, error=0.049
# >epoch=127, lrate=0.500, error=0.049
# >epoch=128, lrate=0.500, error=0.048
# >epoch=129, lrate=0.500, error=0.048
# >epoch=130, lrate=0.500, error=0.047
# >epoch=131, lrate=0.500, error=0.047
# >epoch=132, lrate=0.500, error=0.046
# >epoch=133, lrate=0.500, error=0.046
# >epoch=134, lrate=0.500, error=0.046
# >epoch=135, lrate=0.500, error=0.045
# >epoch=136, lrate=0.500, error=0.045
# >epoch=137, lrate=0.500, error=0.044
# >epoch=138, lrate=0.500, error=0.044
# >epoch=139, lrate=0.500, error=0.043
# >epoch=140, lrate=0.500, error=0.043
# >epoch=141, lrate=0.500, error=0.043
# >epoch=142, lrate=0.500, error=0.042
# >epoch=143, lrate=0.500, error=0.042
# >epoch=144, lrate=0.500, error=0.041
# >epoch=145, lrate=0.500, error=0.041
# >epoch=146, lrate=0.500, error=0.041
# >epoch=147, lrate=0.500, error=0.040
# >epoch=148, lrate=0.500, error=0.040
# >epoch=149, lrate=0.500, error=0.040
# >epoch=150, lrate=0.500, error=0.039
# >epoch=151, lrate=0.500, error=0.039
# >epoch=152, lrate=0.500, error=0.039
# >epoch=153, lrate=0.500, error=0.038
# >epoch=154, lrate=0.500, error=0.038
# >epoch=155, lrate=0.500, error=0.038
# >epoch=156, lrate=0.500, error=0.037
# >epoch=157, lrate=0.500, error=0.037
# >epoch=158, lrate=0.500, error=0.037
# >epoch=159, lrate=0.500, error=0.037
# >epoch=160, lrate=0.500, error=0.036
# >epoch=161, lrate=0.500, error=0.036
# >epoch=162, lrate=0.500, error=0.036
# >epoch=163, lrate=0.500, error=0.035
# >epoch=164, lrate=0.500, error=0.035
# >epoch=165, lrate=0.500, error=0.035
# >epoch=166, lrate=0.500, error=0.035
# >epoch=167, lrate=0.500, error=0.034
# >epoch=168, lrate=0.500, error=0.034
# >epoch=169, lrate=0.500, error=0.034
# >epoch=170, lrate=0.500, error=0.034
# >epoch=171, lrate=0.500, error=0.033
# >epoch=172, lrate=0.500, error=0.033
# >epoch=173, lrate=0.500, error=0.033
# >epoch=174, lrate=0.500, error=0.033
# >epoch=175, lrate=0.500, error=0.032
# >epoch=176, lrate=0.500, error=0.032
# >epoch=177, lrate=0.500, error=0.032
# >epoch=178, lrate=0.500, error=0.032
# >epoch=179, lrate=0.500, error=0.032
# >epoch=180, lrate=0.500, error=0.031
# >epoch=181, lrate=0.500, error=0.031
# >epoch=182, lrate=0.500, error=0.031
# >epoch=183, lrate=0.500, error=0.031
# >epoch=184, lrate=0.500, error=0.030
# >epoch=185, lrate=0.500, error=0.030
# >epoch=186, lrate=0.500, error=0.030
# >epoch=187, lrate=0.500, error=0.030
# >epoch=188, lrate=0.500, error=0.030
# >epoch=189, lrate=0.500, error=0.029
# >epoch=190, lrate=0.500, error=0.029
# >epoch=191, lrate=0.500, error=0.029
# >epoch=192, lrate=0.500, error=0.029
# >epoch=193, lrate=0.500, error=0.029
# >epoch=194, lrate=0.500, error=0.029
# >epoch=195, lrate=0.500, error=0.028
# >epoch=196, lrate=0.500, error=0.028
# >epoch=197, lrate=0.500, error=0.028
# >epoch=198, lrate=0.500, error=0.028
# >epoch=199, lrate=0.500, error=0.028
# >epoch=200, lrate=0.500, error=0.027
# >epoch=201, lrate=0.500, error=0.027
# >epoch=202, lrate=0.500, error=0.027
# >epoch=203, lrate=0.500, error=0.027
# >epoch=204, lrate=0.500, error=0.027
# >epoch=205, lrate=0.500, error=0.027
# >epoch=206, lrate=0.500, error=0.027
# >epoch=207, lrate=0.500, error=0.026
# >epoch=208, lrate=0.500, error=0.026
# >epoch=209, lrate=0.500, error=0.026
# >epoch=210, lrate=0.500, error=0.026
# >epoch=211, lrate=0.500, error=0.026
# >epoch=212, lrate=0.500, error=0.026
# >epoch=213, lrate=0.500, error=0.025
# >epoch=214, lrate=0.500, error=0.025
# >epoch=215, lrate=0.500, error=0.025
# >epoch=216, lrate=0.500, error=0.025
# >epoch=217, lrate=0.500, error=0.025
# >epoch=218, lrate=0.500, error=0.025
# >epoch=219, lrate=0.500, error=0.025
# >epoch=220, lrate=0.500, error=0.024
# >epoch=221, lrate=0.500, error=0.024
# >epoch=222, lrate=0.500, error=0.024
# >epoch=223, lrate=0.500, error=0.024
# >epoch=224, lrate=0.500, error=0.024
# >epoch=225, lrate=0.500, error=0.024
# >epoch=226, lrate=0.500, error=0.024
# >epoch=227, lrate=0.500, error=0.024
# >epoch=228, lrate=0.500, error=0.023
# >epoch=229, lrate=0.500, error=0.023
# >epoch=230, lrate=0.500, error=0.023
# >epoch=231, lrate=0.500, error=0.023
# >epoch=232, lrate=0.500, error=0.023
# >epoch=233, lrate=0.500, error=0.023
# >epoch=234, lrate=0.500, error=0.023
# >epoch=235, lrate=0.500, error=0.023
# >epoch=236, lrate=0.500, error=0.022
# >epoch=237, lrate=0.500, error=0.022
# >epoch=238, lrate=0.500, error=0.022
# >epoch=239, lrate=0.500, error=0.022
# >epoch=240, lrate=0.500, error=0.022
# >epoch=241, lrate=0.500, error=0.022
# >epoch=242, lrate=0.500, error=0.022
# >epoch=243, lrate=0.500, error=0.022
# >epoch=244, lrate=0.500, error=0.022
# >epoch=245, lrate=0.500, error=0.022
# >epoch=246, lrate=0.500, error=0.021
# >epoch=247, lrate=0.500, error=0.021
# >epoch=248, lrate=0.500, error=0.021
# >epoch=249, lrate=0.500, error=0.021
# >epoch=250, lrate=0.500, error=0.021
# >epoch=251, lrate=0.500, error=0.021
# >epoch=252, lrate=0.500, error=0.021
# >epoch=253, lrate=0.500, error=0.021
# >epoch=254, lrate=0.500, error=0.021
# >epoch=255, lrate=0.500, error=0.021
# >epoch=256, lrate=0.500, error=0.020
# >epoch=257, lrate=0.500, error=0.020
# >epoch=258, lrate=0.500, error=0.020
# >epoch=259, lrate=0.500, error=0.020
# >epoch=260, lrate=0.500, error=0.020
# >epoch=261, lrate=0.500, error=0.020
# >epoch=262, lrate=0.500, error=0.020
# >epoch=263, lrate=0.500, error=0.020
# >epoch=264, lrate=0.500, error=0.020
# >epoch=265, lrate=0.500, error=0.020
# >epoch=266, lrate=0.500, error=0.020
# >epoch=267, lrate=0.500, error=0.019
# >epoch=268, lrate=0.500, error=0.019
# >epoch=269, lrate=0.500, error=0.019
# >epoch=270, lrate=0.500, error=0.019
# >epoch=271, lrate=0.500, error=0.019
# >epoch=272, lrate=0.500, error=0.019
# >epoch=273, lrate=0.500, error=0.019
# >epoch=274, lrate=0.500, error=0.019
# >epoch=275, lrate=0.500, error=0.019
# >epoch=276, lrate=0.500, error=0.019
# >epoch=277, lrate=0.500, error=0.019
# >epoch=278, lrate=0.500, error=0.019
# >epoch=279, lrate=0.500, error=0.018
# >epoch=280, lrate=0.500, error=0.018
# >epoch=281, lrate=0.500, error=0.018
# >epoch=282, lrate=0.500, error=0.018
# >epoch=283, lrate=0.500, error=0.018
# >epoch=284, lrate=0.500, error=0.018
# >epoch=285, lrate=0.500, error=0.018
# >epoch=286, lrate=0.500, error=0.018
# >epoch=287, lrate=0.500, error=0.018
# >epoch=288, lrate=0.500, error=0.018
# >epoch=289, lrate=0.500, error=0.018
# >epoch=290, lrate=0.500, error=0.018
# >epoch=291, lrate=0.500, error=0.018
# >epoch=292, lrate=0.500, error=0.018
# >epoch=293, lrate=0.500, error=0.017
# >epoch=294, lrate=0.500, error=0.017
# >epoch=295, lrate=0.500, error=0.017
# >epoch=296, lrate=0.500, error=0.017
# >epoch=297, lrate=0.500, error=0.017
# >epoch=298, lrate=0.500, error=0.017
# >epoch=299, lrate=0.500, error=0.017
# >epoch=300, lrate=0.500, error=0.017
# >epoch=301, lrate=0.500, error=0.017
# >epoch=302, lrate=0.500, error=0.017
# >epoch=303, lrate=0.500, error=0.017
# >epoch=304, lrate=0.500, error=0.017
# >epoch=305, lrate=0.500, error=0.017
# >epoch=306, lrate=0.500, error=0.017
# >epoch=307, lrate=0.500, error=0.017
# >epoch=308, lrate=0.500, error=0.016
# >epoch=309, lrate=0.500, error=0.016
# >epoch=310, lrate=0.500, error=0.016
# >epoch=311, lrate=0.500, error=0.016
# >epoch=312, lrate=0.500, error=0.016
# >epoch=313, lrate=0.500, error=0.016
# >epoch=314, lrate=0.500, error=0.016
# >epoch=315, lrate=0.500, error=0.016
# >epoch=316, lrate=0.500, error=0.016
# >epoch=317, lrate=0.500, error=0.016
# >epoch=318, lrate=0.500, error=0.016
# >epoch=319, lrate=0.500, error=0.016
# >epoch=320, lrate=0.500, error=0.016
# >epoch=321, lrate=0.500, error=0.016
# >epoch=322, lrate=0.500, error=0.016
# >epoch=323, lrate=0.500, error=0.016
# >epoch=324, lrate=0.500, error=0.016
# >epoch=325, lrate=0.500, error=0.015
# >epoch=326, lrate=0.500, error=0.015
# >epoch=327, lrate=0.500, error=0.015
# >epoch=328, lrate=0.500, error=0.015
# >epoch=329, lrate=0.500, error=0.015
# >epoch=330, lrate=0.500, error=0.015
# >epoch=331, lrate=0.500, error=0.015
# >epoch=332, lrate=0.500, error=0.015
# >epoch=333, lrate=0.500, error=0.015
# >epoch=334, lrate=0.500, error=0.015
# >epoch=335, lrate=0.500, error=0.015
# >epoch=336, lrate=0.500, error=0.015
# >epoch=337, lrate=0.500, error=0.015
# >epoch=338, lrate=0.500, error=0.015
# >epoch=339, lrate=0.500, error=0.015
# >epoch=340, lrate=0.500, error=0.015
# >epoch=341, lrate=0.500, error=0.015
# >epoch=342, lrate=0.500, error=0.015
# >epoch=343, lrate=0.500, error=0.015
# >epoch=344, lrate=0.500, error=0.014
# >epoch=345, lrate=0.500, error=0.014
# >epoch=346, lrate=0.500, error=0.014
# >epoch=347, lrate=0.500, error=0.014
# >epoch=348, lrate=0.500, error=0.014
# >epoch=349, lrate=0.500, error=0.014
# >epoch=350, lrate=0.500, error=0.014
# >epoch=351, lrate=0.500, error=0.014
# >epoch=352, lrate=0.500, error=0.014
# >epoch=353, lrate=0.500, error=0.014
# >epoch=354, lrate=0.500, error=0.014
# >epoch=355, lrate=0.500, error=0.014
# >epoch=356, lrate=0.500, error=0.014
# >epoch=357, lrate=0.500, error=0.014
# >epoch=358, lrate=0.500, error=0.014
# >epoch=359, lrate=0.500, error=0.014
# >epoch=360, lrate=0.500, error=0.014
# >epoch=361, lrate=0.500, error=0.014
# >epoch=362, lrate=0.500, error=0.014
# >epoch=363, lrate=0.500, error=0.014
# >epoch=364, lrate=0.500, error=0.014
# >epoch=365, lrate=0.500, error=0.014
# >epoch=366, lrate=0.500, error=0.013
# >epoch=367, lrate=0.500, error=0.013
# >epoch=368, lrate=0.500, error=0.013
# >epoch=369, lrate=0.500, error=0.013
# >epoch=370, lrate=0.500, error=0.013
# >epoch=371, lrate=0.500, error=0.013
# >epoch=372, lrate=0.500, error=0.013
# >epoch=373, lrate=0.500, error=0.013
# >epoch=374, lrate=0.500, error=0.013
# >epoch=375, lrate=0.500, error=0.013
# >epoch=376, lrate=0.500, error=0.013
# >epoch=377, lrate=0.500, error=0.013
# >epoch=378, lrate=0.500, error=0.013
# >epoch=379, lrate=0.500, error=0.013
# >epoch=380, lrate=0.500, error=0.013
# >epoch=381, lrate=0.500, error=0.013
# >epoch=382, lrate=0.500, error=0.013
# >epoch=383, lrate=0.500, error=0.013
# >epoch=384, lrate=0.500, error=0.013
# >epoch=385, lrate=0.500, error=0.013
# >epoch=386, lrate=0.500, error=0.013
# >epoch=387, lrate=0.500, error=0.013
# >epoch=388, lrate=0.500, error=0.013
# >epoch=389, lrate=0.500, error=0.013
# >epoch=390, lrate=0.500, error=0.013
# >epoch=391, lrate=0.500, error=0.013
# >epoch=392, lrate=0.500, error=0.012
# >epoch=393, lrate=0.500, error=0.012
# >epoch=394, lrate=0.500, error=0.012
# >epoch=395, lrate=0.500, error=0.012
# >epoch=396, lrate=0.500, error=0.012
# >epoch=397, lrate=0.500, error=0.012
# >epoch=398, lrate=0.500, error=0.012
# >epoch=399, lrate=0.500, error=0.012
# >epoch=400, lrate=0.500, error=0.012
# >epoch=401, lrate=0.500, error=0.012
# >epoch=402, lrate=0.500, error=0.012
# >epoch=403, lrate=0.500, error=0.012
# >epoch=404, lrate=0.500, error=0.012
# >epoch=405, lrate=0.500, error=0.012
# >epoch=406, lrate=0.500, error=0.012
# >epoch=407, lrate=0.500, error=0.012
# >epoch=408, lrate=0.500, error=0.012
# >epoch=409, lrate=0.500, error=0.012
# >epoch=410, lrate=0.500, error=0.012
# >epoch=411, lrate=0.500, error=0.012
# >epoch=412, lrate=0.500, error=0.012
# >epoch=413, lrate=0.500, error=0.012
# >epoch=414, lrate=0.500, error=0.012
# >epoch=415, lrate=0.500, error=0.012
# >epoch=416, lrate=0.500, error=0.012
# >epoch=417, lrate=0.500, error=0.012
# >epoch=418, lrate=0.500, error=0.012
# >epoch=419, lrate=0.500, error=0.012
# >epoch=420, lrate=0.500, error=0.012
# >epoch=421, lrate=0.500, error=0.012
# >epoch=422, lrate=0.500, error=0.011
# >epoch=423, lrate=0.500, error=0.011
# >epoch=424, lrate=0.500, error=0.011
# >epoch=425, lrate=0.500, error=0.011
# >epoch=426, lrate=0.500, error=0.011
# >epoch=427, lrate=0.500, error=0.011
# >epoch=428, lrate=0.500, error=0.011
# >epoch=429, lrate=0.500, error=0.011
# >epoch=430, lrate=0.500, error=0.011
# >epoch=431, lrate=0.500, error=0.011
# >epoch=432, lrate=0.500, error=0.011
# >epoch=433, lrate=0.500, error=0.011
# >epoch=434, lrate=0.500, error=0.011
# >epoch=435, lrate=0.500, error=0.011
# >epoch=436, lrate=0.500, error=0.011
# >epoch=437, lrate=0.500, error=0.011
# >epoch=438, lrate=0.500, error=0.011
# >epoch=439, lrate=0.500, error=0.011
# >epoch=440, lrate=0.500, error=0.011
# >epoch=441, lrate=0.500, error=0.011
# >epoch=442, lrate=0.500, error=0.011
# >epoch=443, lrate=0.500, error=0.011
# >epoch=444, lrate=0.500, error=0.011
# >epoch=445, lrate=0.500, error=0.011
# >epoch=446, lrate=0.500, error=0.011
# >epoch=447, lrate=0.500, error=0.011
# >epoch=448, lrate=0.500, error=0.011
# >epoch=449, lrate=0.500, error=0.011
# >epoch=450, lrate=0.500, error=0.011
# >epoch=451, lrate=0.500, error=0.011
# >epoch=452, lrate=0.500, error=0.011
# >epoch=453, lrate=0.500, error=0.011
# >epoch=454, lrate=0.500, error=0.011
# >epoch=455, lrate=0.500, error=0.011
# >epoch=456, lrate=0.500, error=0.011
# >epoch=457, lrate=0.500, error=0.011
# >epoch=458, lrate=0.500, error=0.010
# >epoch=459, lrate=0.500, error=0.010
# >epoch=460, lrate=0.500, error=0.010
# >epoch=461, lrate=0.500, error=0.010
# >epoch=462, lrate=0.500, error=0.010
# >epoch=463, lrate=0.500, error=0.010
# >epoch=464, lrate=0.500, error=0.010
# >epoch=465, lrate=0.500, error=0.010
# >epoch=466, lrate=0.500, error=0.010
# >epoch=467, lrate=0.500, error=0.010
# >epoch=468, lrate=0.500, error=0.010
# >epoch=469, lrate=0.500, error=0.010
# >epoch=470, lrate=0.500, error=0.010
# >epoch=471, lrate=0.500, error=0.010
# >epoch=472, lrate=0.500, error=0.010
# >epoch=473, lrate=0.500, error=0.010
# >epoch=474, lrate=0.500, error=0.010
# >epoch=475, lrate=0.500, error=0.010
# >epoch=476, lrate=0.500, error=0.010
# >epoch=477, lrate=0.500, error=0.010
# >epoch=478, lrate=0.500, error=0.010
# >epoch=479, lrate=0.500, error=0.010
# >epoch=480, lrate=0.500, error=0.010
# >epoch=481, lrate=0.500, error=0.010
# >epoch=482, lrate=0.500, error=0.010
# >epoch=483, lrate=0.500, error=0.010
# >epoch=484, lrate=0.500, error=0.010
# >epoch=485, lrate=0.500, error=0.010
# >epoch=486, lrate=0.500, error=0.010
# >epoch=487, lrate=0.500, error=0.010
# >epoch=488, lrate=0.500, error=0.010
# >epoch=489, lrate=0.500, error=0.010
# >epoch=490, lrate=0.500, error=0.010
# >epoch=491, lrate=0.500, error=0.010
# >epoch=492, lrate=0.500, error=0.010
# >epoch=493, lrate=0.500, error=0.010
# >epoch=494, lrate=0.500, error=0.010
# >epoch=495, lrate=0.500, error=0.010
# >epoch=496, lrate=0.500, error=0.010
# >epoch=497, lrate=0.500, error=0.010
# >epoch=498, lrate=0.500, error=0.010
# >epoch=499, lrate=0.500, error=0.010
# >epoch=500, lrate=0.500, error=0.010
# >epoch=501, lrate=0.500, error=0.009
# >epoch=502, lrate=0.500, error=0.009
# >epoch=503, lrate=0.500, error=0.009
# >epoch=504, lrate=0.500, error=0.009
# >epoch=505, lrate=0.500, error=0.009
# >epoch=506, lrate=0.500, error=0.009
# >epoch=507, lrate=0.500, error=0.009
# >epoch=508, lrate=0.500, error=0.009
# >epoch=509, lrate=0.500, error=0.009
# >epoch=510, lrate=0.500, error=0.009
# >epoch=511, lrate=0.500, error=0.009
# >epoch=512, lrate=0.500, error=0.009
# >epoch=513, lrate=0.500, error=0.009
# >epoch=514, lrate=0.500, error=0.009
# >epoch=515, lrate=0.500, error=0.009
# >epoch=516, lrate=0.500, error=0.009
# >epoch=517, lrate=0.500, error=0.009
# >epoch=518, lrate=0.500, error=0.009
# >epoch=519, lrate=0.500, error=0.009
# >epoch=520, lrate=0.500, error=0.009
# >epoch=521, lrate=0.500, error=0.009
# >epoch=522, lrate=0.500, error=0.009
# >epoch=523, lrate=0.500, error=0.009
# >epoch=524, lrate=0.500, error=0.009
# >epoch=525, lrate=0.500, error=0.009
# >epoch=526, lrate=0.500, error=0.009
# >epoch=527, lrate=0.500, error=0.009
# >epoch=528, lrate=0.500, error=0.009
# >epoch=529, lrate=0.500, error=0.009
# >epoch=530, lrate=0.500, error=0.009
# >epoch=531, lrate=0.500, error=0.009
# >epoch=532, lrate=0.500, error=0.009
# >epoch=533, lrate=0.500, error=0.009
# >epoch=534, lrate=0.500, error=0.009
# >epoch=535, lrate=0.500, error=0.009
# >epoch=536, lrate=0.500, error=0.009
# >epoch=537, lrate=0.500, error=0.009
# >epoch=538, lrate=0.500, error=0.009
# >epoch=539, lrate=0.500, error=0.009
# >epoch=540, lrate=0.500, error=0.009
# >epoch=541, lrate=0.500, error=0.009
# >epoch=542, lrate=0.500, error=0.009
# >epoch=543, lrate=0.500, error=0.009
# >epoch=544, lrate=0.500, error=0.009
# >epoch=545, lrate=0.500, error=0.009
# >epoch=546, lrate=0.500, error=0.009
# >epoch=547, lrate=0.500, error=0.009
# >epoch=548, lrate=0.500, error=0.009
# >epoch=549, lrate=0.500, error=0.009
# >epoch=550, lrate=0.500, error=0.009
# >epoch=551, lrate=0.500, error=0.009
# >epoch=552, lrate=0.500, error=0.009
# >epoch=553, lrate=0.500, error=0.009
# >epoch=554, lrate=0.500, error=0.008
# >epoch=555, lrate=0.500, error=0.008
# >epoch=556, lrate=0.500, error=0.008
# >epoch=557, lrate=0.500, error=0.008
# >epoch=558, lrate=0.500, error=0.008
# >epoch=559, lrate=0.500, error=0.008
# >epoch=560, lrate=0.500, error=0.008
# >epoch=561, lrate=0.500, error=0.008
# >epoch=562, lrate=0.500, error=0.008
# >epoch=563, lrate=0.500, error=0.008
# >epoch=564, lrate=0.500, error=0.008
# >epoch=565, lrate=0.500, error=0.008
# >epoch=566, lrate=0.500, error=0.008
# >epoch=567, lrate=0.500, error=0.008
# >epoch=568, lrate=0.500, error=0.008
# >epoch=569, lrate=0.500, error=0.008
# >epoch=570, lrate=0.500, error=0.008
# >epoch=571, lrate=0.500, error=0.008
# >epoch=572, lrate=0.500, error=0.008
# >epoch=573, lrate=0.500, error=0.008
# >epoch=574, lrate=0.500, error=0.008
# >epoch=575, lrate=0.500, error=0.008
# >epoch=576, lrate=0.500, error=0.008
# >epoch=577, lrate=0.500, error=0.008
# >epoch=578, lrate=0.500, error=0.008
# >epoch=579, lrate=0.500, error=0.008
# >epoch=580, lrate=0.500, error=0.008
# >epoch=581, lrate=0.500, error=0.008
# >epoch=582, lrate=0.500, error=0.008
# >epoch=583, lrate=0.500, error=0.008
# >epoch=584, lrate=0.500, error=0.008
# >epoch=585, lrate=0.500, error=0.008
# >epoch=586, lrate=0.500, error=0.008
# >epoch=587, lrate=0.500, error=0.008
# >epoch=588, lrate=0.500, error=0.008
# >epoch=589, lrate=0.500, error=0.008
# >epoch=590, lrate=0.500, error=0.008
# >epoch=591, lrate=0.500, error=0.008
# >epoch=592, lrate=0.500, error=0.008
# >epoch=593, lrate=0.500, error=0.008
# >epoch=594, lrate=0.500, error=0.008
# >epoch=595, lrate=0.500, error=0.008
# >epoch=596, lrate=0.500, error=0.008
# >epoch=597, lrate=0.500, error=0.008
# >epoch=598, lrate=0.500, error=0.008
# >epoch=599, lrate=0.500, error=0.008
# >epoch=600, lrate=0.500, error=0.008
# >epoch=601, lrate=0.500, error=0.008
# >epoch=602, lrate=0.500, error=0.008
# >epoch=603, lrate=0.500, error=0.008
# >epoch=604, lrate=0.500, error=0.008
# >epoch=605, lrate=0.500, error=0.008
# >epoch=606, lrate=0.500, error=0.008
# >epoch=607, lrate=0.500, error=0.008
# >epoch=608, lrate=0.500, error=0.008
# >epoch=609, lrate=0.500, error=0.008
# >epoch=610, lrate=0.500, error=0.008
# >epoch=611, lrate=0.500, error=0.008
# >epoch=612, lrate=0.500, error=0.008
# >epoch=613, lrate=0.500, error=0.008
# >epoch=614, lrate=0.500, error=0.008
# >epoch=615, lrate=0.500, error=0.008
# >epoch=616, lrate=0.500, error=0.008
# >epoch=617, lrate=0.500, error=0.008
# >epoch=618, lrate=0.500, error=0.008
# >epoch=619, lrate=0.500, error=0.008
# >epoch=620, lrate=0.500, error=0.008
# >epoch=621, lrate=0.500, error=0.007
# >epoch=622, lrate=0.500, error=0.007
# >epoch=623, lrate=0.500, error=0.007
# >epoch=624, lrate=0.500, error=0.007
# >epoch=625, lrate=0.500, error=0.007
# >epoch=626, lrate=0.500, error=0.007
# >epoch=627, lrate=0.500, error=0.007
# >epoch=628, lrate=0.500, error=0.007
# >epoch=629, lrate=0.500, error=0.007
# >epoch=630, lrate=0.500, error=0.007
# >epoch=631, lrate=0.500, error=0.007
# >epoch=632, lrate=0.500, error=0.007
# >epoch=633, lrate=0.500, error=0.007
# >epoch=634, lrate=0.500, error=0.007
# >epoch=635, lrate=0.500, error=0.007
# >epoch=636, lrate=0.500, error=0.007
# >epoch=637, lrate=0.500, error=0.007
# >epoch=638, lrate=0.500, error=0.007
# >epoch=639, lrate=0.500, error=0.007
# >epoch=640, lrate=0.500, error=0.007
# >epoch=641, lrate=0.500, error=0.007
# >epoch=642, lrate=0.500, error=0.007
# >epoch=643, lrate=0.500, error=0.007
# >epoch=644, lrate=0.500, error=0.007
# >epoch=645, lrate=0.500, error=0.007
# >epoch=646, lrate=0.500, error=0.007
# >epoch=647, lrate=0.500, error=0.007
# >epoch=648, lrate=0.500, error=0.007
# >epoch=649, lrate=0.500, error=0.007
# >epoch=650, lrate=0.500, error=0.007
# >epoch=651, lrate=0.500, error=0.007
# >epoch=652, lrate=0.500, error=0.007
# >epoch=653, lrate=0.500, error=0.007
# >epoch=654, lrate=0.500, error=0.007
# >epoch=655, lrate=0.500, error=0.007
# >epoch=656, lrate=0.500, error=0.007
# >epoch=657, lrate=0.500, error=0.007
# >epoch=658, lrate=0.500, error=0.007
# >epoch=659, lrate=0.500, error=0.007
# >epoch=660, lrate=0.500, error=0.007
# >epoch=661, lrate=0.500, error=0.007
# >epoch=662, lrate=0.500, error=0.007
# >epoch=663, lrate=0.500, error=0.007
# >epoch=664, lrate=0.500, error=0.007
# >epoch=665, lrate=0.500, error=0.007
# >epoch=666, lrate=0.500, error=0.007
# >epoch=667, lrate=0.500, error=0.007
# >epoch=668, lrate=0.500, error=0.007
# >epoch=669, lrate=0.500, error=0.007
# >epoch=670, lrate=0.500, error=0.007
# >epoch=671, lrate=0.500, error=0.007
# >epoch=672, lrate=0.500, error=0.007
# >epoch=673, lrate=0.500, error=0.007
# >epoch=674, lrate=0.500, error=0.007
# >epoch=675, lrate=0.500, error=0.007
# >epoch=676, lrate=0.500, error=0.007
# >epoch=677, lrate=0.500, error=0.007
# >epoch=678, lrate=0.500, error=0.007
# >epoch=679, lrate=0.500, error=0.007
# >epoch=680, lrate=0.500, error=0.007
# >epoch=681, lrate=0.500, error=0.007
# >epoch=682, lrate=0.500, error=0.007
# >epoch=683, lrate=0.500, error=0.007
# >epoch=684, lrate=0.500, error=0.007
# >epoch=685, lrate=0.500, error=0.007
# >epoch=686, lrate=0.500, error=0.007
# >epoch=687, lrate=0.500, error=0.007
# >epoch=688, lrate=0.500, error=0.007
# >epoch=689, lrate=0.500, error=0.007
# >epoch=690, lrate=0.500, error=0.007
# >epoch=691, lrate=0.500, error=0.007
# >epoch=692, lrate=0.500, error=0.007
# >epoch=693, lrate=0.500, error=0.007
# >epoch=694, lrate=0.500, error=0.007
# >epoch=695, lrate=0.500, error=0.007
# >epoch=696, lrate=0.500, error=0.007
# >epoch=697, lrate=0.500, error=0.007
# >epoch=698, lrate=0.500, error=0.007
# >epoch=699, lrate=0.500, error=0.007
# >epoch=700, lrate=0.500, error=0.007
# >epoch=701, lrate=0.500, error=0.007
# >epoch=702, lrate=0.500, error=0.007
# >epoch=703, lrate=0.500, error=0.007
# >epoch=704, lrate=0.500, error=0.007
# >epoch=705, lrate=0.500, error=0.007
# >epoch=706, lrate=0.500, error=0.007
# >epoch=707, lrate=0.500, error=0.007
# >epoch=708, lrate=0.500, error=0.006
# >epoch=709, lrate=0.500, error=0.006
# >epoch=710, lrate=0.500, error=0.006
# >epoch=711, lrate=0.500, error=0.006
# >epoch=712, lrate=0.500, error=0.006
# >epoch=713, lrate=0.500, error=0.006
# >epoch=714, lrate=0.500, error=0.006
# >epoch=715, lrate=0.500, error=0.006
# >epoch=716, lrate=0.500, error=0.006
# >epoch=717, lrate=0.500, error=0.006
# >epoch=718, lrate=0.500, error=0.006
# >epoch=719, lrate=0.500, error=0.006
# >epoch=720, lrate=0.500, error=0.006
# >epoch=721, lrate=0.500, error=0.006
# >epoch=722, lrate=0.500, error=0.006
# >epoch=723, lrate=0.500, error=0.006
# >epoch=724, lrate=0.500, error=0.006
# >epoch=725, lrate=0.500, error=0.006
# >epoch=726, lrate=0.500, error=0.006
# >epoch=727, lrate=0.500, error=0.006
# >epoch=728, lrate=0.500, error=0.006
# >epoch=729, lrate=0.500, error=0.006
# >epoch=730, lrate=0.500, error=0.006
# >epoch=731, lrate=0.500, error=0.006
# >epoch=732, lrate=0.500, error=0.006
# >epoch=733, lrate=0.500, error=0.006
# >epoch=734, lrate=0.500, error=0.006
# >epoch=735, lrate=0.500, error=0.006
# >epoch=736, lrate=0.500, error=0.006
# >epoch=737, lrate=0.500, error=0.006
# >epoch=738, lrate=0.500, error=0.006
# >epoch=739, lrate=0.500, error=0.006
# >epoch=740, lrate=0.500, error=0.006
# >epoch=741, lrate=0.500, error=0.006
# >epoch=742, lrate=0.500, error=0.006
# >epoch=743, lrate=0.500, error=0.006
# >epoch=744, lrate=0.500, error=0.006
# >epoch=745, lrate=0.500, error=0.006
# >epoch=746, lrate=0.500, error=0.006
# >epoch=747, lrate=0.500, error=0.006
# >epoch=748, lrate=0.500, error=0.006
# >epoch=749, lrate=0.500, error=0.006
# >epoch=750, lrate=0.500, error=0.006
# >epoch=751, lrate=0.500, error=0.006
# >epoch=752, lrate=0.500, error=0.006
# >epoch=753, lrate=0.500, error=0.006
# >epoch=754, lrate=0.500, error=0.006
# >epoch=755, lrate=0.500, error=0.006
# >epoch=756, lrate=0.500, error=0.006
# >epoch=757, lrate=0.500, error=0.006
# >epoch=758, lrate=0.500, error=0.006
# >epoch=759, lrate=0.500, error=0.006
# >epoch=760, lrate=0.500, error=0.006
# >epoch=761, lrate=0.500, error=0.006
# >epoch=762, lrate=0.500, error=0.006
# >epoch=763, lrate=0.500, error=0.006
# >epoch=764, lrate=0.500, error=0.006
# >epoch=765, lrate=0.500, error=0.006
# >epoch=766, lrate=0.500, error=0.006
# >epoch=767, lrate=0.500, error=0.006
# >epoch=768, lrate=0.500, error=0.006
# >epoch=769, lrate=0.500, error=0.006
# >epoch=770, lrate=0.500, error=0.006
# >epoch=771, lrate=0.500, error=0.006
# >epoch=772, lrate=0.500, error=0.006
# >epoch=773, lrate=0.500, error=0.006
# >epoch=774, lrate=0.500, error=0.006
# >epoch=775, lrate=0.500, error=0.006
# >epoch=776, lrate=0.500, error=0.006
# >epoch=777, lrate=0.500, error=0.006
# >epoch=778, lrate=0.500, error=0.006
# >epoch=779, lrate=0.500, error=0.006
# >epoch=780, lrate=0.500, error=0.006
# >epoch=781, lrate=0.500, error=0.006
# >epoch=782, lrate=0.500, error=0.006
# >epoch=783, lrate=0.500, error=0.006
# >epoch=784, lrate=0.500, error=0.006
# >epoch=785, lrate=0.500, error=0.006
# >epoch=786, lrate=0.500, error=0.006
# >epoch=787, lrate=0.500, error=0.006
# >epoch=788, lrate=0.500, error=0.006
# >epoch=789, lrate=0.500, error=0.006
# >epoch=790, lrate=0.500, error=0.006
# >epoch=791, lrate=0.500, error=0.006
# >epoch=792, lrate=0.500, error=0.006
# >epoch=793, lrate=0.500, error=0.006
# >epoch=794, lrate=0.500, error=0.006
# >epoch=795, lrate=0.500, error=0.006
# >epoch=796, lrate=0.500, error=0.006
# >epoch=797, lrate=0.500, error=0.006
# >epoch=798, lrate=0.500, error=0.006
# >epoch=799, lrate=0.500, error=0.006
# >epoch=800, lrate=0.500, error=0.006
# >epoch=801, lrate=0.500, error=0.006
# >epoch=802, lrate=0.500, error=0.006
# >epoch=803, lrate=0.500, error=0.006
# >epoch=804, lrate=0.500, error=0.006
# >epoch=805, lrate=0.500, error=0.006
# >epoch=806, lrate=0.500, error=0.006
# >epoch=807, lrate=0.500, error=0.006
# >epoch=808, lrate=0.500, error=0.006
# >epoch=809, lrate=0.500, error=0.006
# >epoch=810, lrate=0.500, error=0.006
# >epoch=811, lrate=0.500, error=0.006
# >epoch=812, lrate=0.500, error=0.006
# >epoch=813, lrate=0.500, error=0.006
# >epoch=814, lrate=0.500, error=0.006
# >epoch=815, lrate=0.500, error=0.006
# >epoch=816, lrate=0.500, error=0.006
# >epoch=817, lrate=0.500, error=0.006
# >epoch=818, lrate=0.500, error=0.006
# >epoch=819, lrate=0.500, error=0.006
# >epoch=820, lrate=0.500, error=0.006
# >epoch=821, lrate=0.500, error=0.006
# >epoch=822, lrate=0.500, error=0.006
# >epoch=823, lrate=0.500, error=0.006
# >epoch=824, lrate=0.500, error=0.006
# >epoch=825, lrate=0.500, error=0.006
# >epoch=826, lrate=0.500, error=0.005
# >epoch=827, lrate=0.500, error=0.005
# >epoch=828, lrate=0.500, error=0.005
# >epoch=829, lrate=0.500, error=0.005
# >epoch=830, lrate=0.500, error=0.005
# >epoch=831, lrate=0.500, error=0.005
# >epoch=832, lrate=0.500, error=0.005
# >epoch=833, lrate=0.500, error=0.005
# >epoch=834, lrate=0.500, error=0.005
# >epoch=835, lrate=0.500, error=0.005
# >epoch=836, lrate=0.500, error=0.005
# >epoch=837, lrate=0.500, error=0.005
# >epoch=838, lrate=0.500, error=0.005
# >epoch=839, lrate=0.500, error=0.005
# >epoch=840, lrate=0.500, error=0.005
# >epoch=841, lrate=0.500, error=0.005
# >epoch=842, lrate=0.500, error=0.005
# >epoch=843, lrate=0.500, error=0.005
# >epoch=844, lrate=0.500, error=0.005
# >epoch=845, lrate=0.500, error=0.005
# >epoch=846, lrate=0.500, error=0.005
# >epoch=847, lrate=0.500, error=0.005
# >epoch=848, lrate=0.500, error=0.005
# >epoch=849, lrate=0.500, error=0.005
# >epoch=850, lrate=0.500, error=0.005
# >epoch=851, lrate=0.500, error=0.005
# >epoch=852, lrate=0.500, error=0.005
# >epoch=853, lrate=0.500, error=0.005
# >epoch=854, lrate=0.500, error=0.005
# >epoch=855, lrate=0.500, error=0.005
# >epoch=856, lrate=0.500, error=0.005
# >epoch=857, lrate=0.500, error=0.005
# >epoch=858, lrate=0.500, error=0.005
# >epoch=859, lrate=0.500, error=0.005
# >epoch=860, lrate=0.500, error=0.005
# >epoch=861, lrate=0.500, error=0.005
# >epoch=862, lrate=0.500, error=0.005
# >epoch=863, lrate=0.500, error=0.005
# >epoch=864, lrate=0.500, error=0.005
# >epoch=865, lrate=0.500, error=0.005
# >epoch=866, lrate=0.500, error=0.005
# >epoch=867, lrate=0.500, error=0.005
# >epoch=868, lrate=0.500, error=0.005
# >epoch=869, lrate=0.500, error=0.005
# >epoch=870, lrate=0.500, error=0.005
# >epoch=871, lrate=0.500, error=0.005
# >epoch=872, lrate=0.500, error=0.005
# >epoch=873, lrate=0.500, error=0.005
# >epoch=874, lrate=0.500, error=0.005
# >epoch=875, lrate=0.500, error=0.005
# >epoch=876, lrate=0.500, error=0.005
# >epoch=877, lrate=0.500, error=0.005
# >epoch=878, lrate=0.500, error=0.005
# >epoch=879, lrate=0.500, error=0.005
# >epoch=880, lrate=0.500, error=0.005
# >epoch=881, lrate=0.500, error=0.005
# >epoch=882, lrate=0.500, error=0.005
# >epoch=883, lrate=0.500, error=0.005
# >epoch=884, lrate=0.500, error=0.005
# >epoch=885, lrate=0.500, error=0.005
# >epoch=886, lrate=0.500, error=0.005
# >epoch=887, lrate=0.500, error=0.005
# >epoch=888, lrate=0.500, error=0.005
# >epoch=889, lrate=0.500, error=0.005
# >epoch=890, lrate=0.500, error=0.005
# >epoch=891, lrate=0.500, error=0.005
# >epoch=892, lrate=0.500, error=0.005
# >epoch=893, lrate=0.500, error=0.005
# >epoch=894, lrate=0.500, error=0.005
# >epoch=895, lrate=0.500, error=0.005
# >epoch=896, lrate=0.500, error=0.005
# >epoch=897, lrate=0.500, error=0.005
# >epoch=898, lrate=0.500, error=0.005
# >epoch=899, lrate=0.500, error=0.005
# >epoch=900, lrate=0.500, error=0.005
# >epoch=901, lrate=0.500, error=0.005
# >epoch=902, lrate=0.500, error=0.005
# >epoch=903, lrate=0.500, error=0.005
# >epoch=904, lrate=0.500, error=0.005
# >epoch=905, lrate=0.500, error=0.005
# >epoch=906, lrate=0.500, error=0.005
# >epoch=907, lrate=0.500, error=0.005
# >epoch=908, lrate=0.500, error=0.005
# >epoch=909, lrate=0.500, error=0.005
# >epoch=910, lrate=0.500, error=0.005
# >epoch=911, lrate=0.500, error=0.005
# >epoch=912, lrate=0.500, error=0.005
# >epoch=913, lrate=0.500, error=0.005
# >epoch=914, lrate=0.500, error=0.005
# >epoch=915, lrate=0.500, error=0.005
# >epoch=916, lrate=0.500, error=0.005
# >epoch=917, lrate=0.500, error=0.005
# >epoch=918, lrate=0.500, error=0.005
# >epoch=919, lrate=0.500, error=0.005
# >epoch=920, lrate=0.500, error=0.005
# >epoch=921, lrate=0.500, error=0.005
# >epoch=922, lrate=0.500, error=0.005
# >epoch=923, lrate=0.500, error=0.005
# >epoch=924, lrate=0.500, error=0.005
# >epoch=925, lrate=0.500, error=0.005
# >epoch=926, lrate=0.500, error=0.005
# >epoch=927, lrate=0.500, error=0.005
# >epoch=928, lrate=0.500, error=0.005
# >epoch=929, lrate=0.500, error=0.005
# >epoch=930, lrate=0.500, error=0.005
# >epoch=931, lrate=0.500, error=0.005
# >epoch=932, lrate=0.500, error=0.005
# >epoch=933, lrate=0.500, error=0.005
# >epoch=934, lrate=0.500, error=0.005
# >epoch=935, lrate=0.500, error=0.005
# >epoch=936, lrate=0.500, error=0.005
# >epoch=937, lrate=0.500, error=0.005
# >epoch=938, lrate=0.500, error=0.005
# >epoch=939, lrate=0.500, error=0.005
# >epoch=940, lrate=0.500, error=0.005
# >epoch=941, lrate=0.500, error=0.005
# >epoch=942, lrate=0.500, error=0.005
# >epoch=943, lrate=0.500, error=0.005
# >epoch=944, lrate=0.500, error=0.005
# >epoch=945, lrate=0.500, error=0.005
# >epoch=946, lrate=0.500, error=0.005
# >epoch=947, lrate=0.500, error=0.005
# >epoch=948, lrate=0.500, error=0.005
# >epoch=949, lrate=0.500, error=0.005
# >epoch=950, lrate=0.500, error=0.005
# >epoch=951, lrate=0.500, error=0.005
# >epoch=952, lrate=0.500, error=0.005
# >epoch=953, lrate=0.500, error=0.005
# >epoch=954, lrate=0.500, error=0.005
# >epoch=955, lrate=0.500, error=0.005
# >epoch=956, lrate=0.500, error=0.005
# >epoch=957, lrate=0.500, error=0.005
# >epoch=958, lrate=0.500, error=0.005
# >epoch=959, lrate=0.500, error=0.005
# >epoch=960, lrate=0.500, error=0.005
# >epoch=961, lrate=0.500, error=0.005
# >epoch=962, lrate=0.500, error=0.005
# >epoch=963, lrate=0.500, error=0.005
# >epoch=964, lrate=0.500, error=0.005
# >epoch=965, lrate=0.500, error=0.005
# >epoch=966, lrate=0.500, error=0.005
# >epoch=967, lrate=0.500, error=0.005
# >epoch=968, lrate=0.500, error=0.005
# >epoch=969, lrate=0.500, error=0.005
# >epoch=970, lrate=0.500, error=0.005
# >epoch=971, lrate=0.500, error=0.005
# >epoch=972, lrate=0.500, error=0.005
# >epoch=973, lrate=0.500, error=0.005
# >epoch=974, lrate=0.500, error=0.005
# >epoch=975, lrate=0.500, error=0.005
# >epoch=976, lrate=0.500, error=0.005
# >epoch=977, lrate=0.500, error=0.005
# >epoch=978, lrate=0.500, error=0.005
# >epoch=979, lrate=0.500, error=0.005
# >epoch=980, lrate=0.500, error=0.005
# >epoch=981, lrate=0.500, error=0.005
# >epoch=982, lrate=0.500, error=0.005
# >epoch=983, lrate=0.500, error=0.005
# >epoch=984, lrate=0.500, error=0.005
# >epoch=985, lrate=0.500, error=0.005
# >epoch=986, lrate=0.500, error=0.005
# >epoch=987, lrate=0.500, error=0.005
# >epoch=988, lrate=0.500, error=0.005
# >epoch=989, lrate=0.500, error=0.005
# >epoch=990, lrate=0.500, error=0.005
# >epoch=991, lrate=0.500, error=0.005
# >epoch=992, lrate=0.500, error=0.005
# >epoch=993, lrate=0.500, error=0.005
# >epoch=994, lrate=0.500, error=0.005
# >epoch=995, lrate=0.500, error=0.005
# >epoch=996, lrate=0.500, error=0.004
# >epoch=997, lrate=0.500, error=0.004
# >epoch=998, lrate=0.500, error=0.004
# >epoch=999, lrate=0.500, error=0.004
